# %%
# pip install langchain-community

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data.txt")
print(type(loader))
documents = loader.load()

print(documents[0].page_content)
# Out:
# <class 'langchain_community.document_loaders.text.TextLoader'>
# Artificial Intelligence: Transforming the World Around Us
#
# Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever created by humanity. It has transformed industries, changed the way people interact with machines, and continues to shape the future of society. AI refers to the ability of machines and computer systems to perform tasks that normally require human intelligence. These tasks include learning, reasoning, decision-making, language understanding, visual recognition, and problem-solving.
#
# ...

# %%
# pip install langchain

# %%
# pip install langchain-text-splitters

# %%
# install langchain if not already available
# !pip install langchain
from langchain_text_splitters import RecursiveCharacterTextSplitter

# from langchain.text_splitter import RecursiveCharacterTextSplitter
# from langchain_text_splitter import Re

# %%
chunking = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)
#split_text
s='''
Artificial Intelligence: Transforming the World Around Us.Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever created by humanity. It has transformed industries, changed the way people interact with machines, and continues to shape the future of society. AI refers to the ability of machines and computer systems to perform tasks that normally require human intelligence. These tasks include learning, reasoning, decision-making, language understanding, visual recognition, and problem-solving.
'''
result = chunking.split_text(s)
for val in result:
    print(len(val),val)
# Out:
# 97 Artificial Intelligence: Transforming the World Around Us.Artificial Intelligence, commonly known
# 96 commonly known as AI, is one of the most revolutionary technologies ever created by humanity. It
# 94 by humanity. It has transformed industries, changed the way people interact with machines, and
# 97 with machines, and continues to shape the future of society. AI refers to the ability of machines
# 99 ability of machines and computer systems to perform tasks that normally require human intelligence.
# 86 human intelligence. These tasks include learning, reasoning, decision-making, language
# 64 language understanding, visual recognition, and problem-solving.

# %%
result= chunking.split_documents(documents)

# %%
result
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='Artificial Intelligence: Transforming the World Around Us'),
#  Document(metadata={'source': 'data.txt'}, page_content='Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever'),
#  Document(metadata={'source': 'data.txt'}, page_content='technologies ever created by humanity. It has transformed industries, changed the way people'),
#  Document(metadata={'source': 'data.txt'}, page_content='the way people interact with machines, and continues to shape the future of society. AI refers to'),
#  Document(metadata={'source': 'data.txt'}, page_content='AI refers to the ability of machines and computer systems to perform tasks that normally require'),
#  Document(metadata={'source': 'data.txt'}, page_content='normally require human intelligence. These tasks include learning, reasoning, decision-making,'),
# ...

# %%
result
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='Artificial Intelligence: Transforming the World Around Us'),
#  Document(metadata={'source': 'data.txt'}, page_content='Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever'),
#  Document(metadata={'source': 'data.txt'}, page_content='technologies ever created by humanity. It has transformed industries, changed the way people'),
#  Document(metadata={'source': 'data.txt'}, page_content='the way people interact with machines, and continues to shape the future of society. AI refers to'),
#  Document(metadata={'source': 'data.txt'}, page_content='AI refers to the ability of machines and computer systems to perform tasks that normally require'),
#  Document(metadata={'source': 'data.txt'}, page_content='normally require human intelligence. These tasks include learning, reasoning, decision-making,'),
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
embed_model
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2682.18it/s]
# HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, query_encode_kwargs={}, multi_process=False, show_progress=False)

# %%
# for chunk in result:
#     print(chunk.page_content)

texts = [chunk.page_content for chunk in result]
texts
# Out:
# ['Artificial Intelligence: Transforming the World Around Us',
#  'Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever',
#  'technologies ever created by humanity. It has transformed industries, changed the way people',
#  'the way people interact with machines, and continues to shape the future of society. AI refers to',
#  'AI refers to the ability of machines and computer systems to perform tasks that normally require',
#  'normally require human intelligence. These tasks include learning, reasoning, decision-making,',
#  'decision-making, language understanding, visual recognition, and problem-solving.',
#  'The idea of intelligent machines has existed for centuries. Ancient myths and stories often',
#  'and stories often described mechanical beings capable of thinking and acting like humans. However,',
#  'humans. However, modern AI research officially began in the 1950s when scientists started exploring',
# ...

# %%
embeddings = embed_model.embed_documents(texts)

# %%
print(len(embeddings[0]))
# Out:
# 384

# %%
# result[0].metadata['h']=100
# result

# %%
tuple(zip(result, embeddings))[1]
# Out:
# (Document(metadata={'source': 'data.txt'}, page_content='Artificial Intelligence, commonly known as AI, is one of the most revolutionary technologies ever'),
#  [-0.020377356559038162,
#   -0.017884494736790657,
#   0.0016135849291458726,
#   -0.03661159425973892,
#   0.01008076686412096,
#   -0.03150032460689545,
#   0.026855746284127235,
#   0.0513087697327137,
#   -0.021539295092225075,
#   0.04212626442313194,
#   -0.04044192656874657,
#   0.09063267707824707,
#   0.04408620670437813,
#   -0.0006453023524954915,
#   -0.0575655922293663,
#   0.06511574238538742,
#   -0.04528694227337837,
#   -0.06241698935627937,
#   -0.07442910969257355,
#   -0.08340799063444138,
#   0.0008073439821600914,
#   -0.011121606454253197,
#   0.031857073307037354,
#   -0.06698571145534515,
#   0.03933623433113098,
#   0.06470853835344315,
#   0.022400526329874992,
#   -0.10938280075788498,
#   -0.016131265088915825,
#   -0.0017179329879581928,
#   0.0035331964027136564,
#   0.01206284761428833,
# ...

# %%
for doc, emb in zip(result, embeddings):
    doc.metadata["hf_embedding"] = emb
result
# Out:
# [Document(metadata={'source': 'data.txt', 'hf_embedding': [0.04175811633467674, -0.013241720385849476, 0.05674145370721817, -0.0011852862080559134, 0.05145769566297531, -0.024291465058922768, -0.04658498242497444, 0.008199227973818779, -0.032366205006837845, -0.004108873661607504, -0.017724044620990753, 0.057142917066812515, 0.022848185151815414, 0.03168725594878197, -0.07795720547437668, 0.003513419535011053, -0.07169148325920105, -0.024305932223796844, -0.15420126914978027, -0.10426460206508636, 0.02517131343483925, 0.023329677060246468, -0.00407384755089879, -0.018674559891223907, -0.021510127931833267, 0.047664519399404526, 0.03776974603533745, -0.051876503974199295, -0.04994231089949608, -0.09630785137414932, 0.05271847918629646, -0.00784977525472641, 0.048134684562683105, -0.010518280789256096, 0.007241311017423868, 0.08388660848140717, 0.004737337585538626, -0.04564720392227173, 0.04293707385659218, -0.03330766782164574, 0.022076178342103958, -0.07932046055793762, 0.0110528394
# ...

# %%
from langchain_community.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI

vectorstore = FAISS.from_documents(result,embed_model)
model = ChatGoogleGenerativeAI(
    model = 'gemini-2.5-flash',
    api_key = "AIzaSyDO4GsJio6Flrs5gxOezoSfuqvGI_EKpFs"
)
def rag_query(query,top=2):
    docs = vectorstore.similarity_search(query,top)
    chunks = '\n\n'.join([doc.page_content for doc in docs])
    return chunks

answer = rag_query('what is deep learning ?')

answer
# Out:
# 'Deep learning is a subset of machine learning that uses artificial neural networks inspired by the\n\ninspired by the structure of the human brain. Deep learning models contain multiple layers of'

# %%
from langchain_community.vectorstores import FAISS
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages  import HumanMessage, SystemMessage

vectorstore = FAISS.from_documents(result, embed_model)

chat_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0, 
    api_key="AIzaSyDO4GsJio6Flrs5gxOezoSfuqvGI_EKpFs"
)
def rag_query(query: str, k: int = 4):
    # build context and prompt, then call the model using .generate()
    docs = vectorstore.similarity_search(query, k=4)
    context = "\n\n".join(doc.page_content for doc in docs)
    prompt = (
        "Use the following context to answer the question.\n\n"
        f"Context:\n{context}\n\n"
        f"Question: {query}\n"
        "Answer only using the context. If the answer is not contained in the context, say you do not know."
    )

    result = chat_model.generate([[SystemMessage(content="You are a helpful assistant."), HumanMessage(content=prompt)]])

    # extract text from possible return shapes
    try:
        rag_answer = result.generations[0][0].text
    except Exception:
        rag_answer = result.generations[0][0].message.content

    return rag_answer

print("Number of documents in result:", len(result))
try:
    print("Number of vectors in FAISS index:", vectorstore.index.ntotal)
except Exception as e:
    print("Could not read FAISS vector count:", e)

query = "What tasks can AI perform?"

print("\nRAG answer:",rag_query(query))
# Out:
# Number of documents in result: 158
# Number of vectors in FAISS index: 158
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\Administrator\OneDrive\Desktop\GEN_AI3\genai\Lib\site-packages\langchain_google_genai\chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File c:\Users\Administrator\OneDrive\Desktop\GEN_AI3\genai\Lib\site-packages\google\genai\models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
# ...

# %%
from langchain_core.prompts import PromptTemplate

summarization_prompt = PromptTemplate(
    input_variables=["query"],
    template=(
        "Given the question below, generate a short retrieval query or key phrases "
        "to find the most relevant documents.\n\nQuestion: {query}\n\nRetrieval query:"
    ),
)

answer_prompt = PromptTemplate(
    input_variables=["query", "context"],
    template=(
        "Use only the context below to answer the question.\n\nContext:\n{context}\n\n"
        "Question: {query}\n\nAnswer:"
    ),
)

summarization_chain = LLMChain(llm=chat_model, prompt=summarization_prompt)
answer_chain = LLMChain(llm=chat_model, prompt=answer_prompt)

def prompt_chain_rag(query: str, k: int = 4):
    retrieval_query = summarization_chain.run(query)
    docs = vectorstore.similarity_search(retrieval_query, k=k)
    context = "\n\n".join(doc.page_content for doc in docs)
    return answer_chain.run({"query": query, "context": context})

print(prompt_chain_rag("What tasks can AI perform?"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain import PromptTemplate, LLMChain
#       2
#       3 summarization_prompt = PromptTemplate(
#       4     input_variables=["query"],
#
# ImportError: cannot import name 'PromptTemplate' from 'langchain' (c:\Users\Administrator\OneDrive\Desktop\GEN_AI3\genai\Lib\site-packages\langchain\__init__.py)
